# %% [markdown]
# # 01_04: Comprehensions

# %%
import math
import collections
import dataclasses
import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
import math
import collections
import dataclasses
import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
squares = []
for i in range(1, 11):
    squares.append(i**2)

# %%
cubes = []
for i in range(0, 11):
  cubes.append(i**3)

# %%
squares
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
cubes
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]

# %%
squares = [i**2 for i in range(1, 11)]

# %%
quadrup = [i**4 for i in range(0, 11)]

# %%
quadrup
# Out:
# [0, 1, 16, 81, 256, 625, 1296, 2401, 4096, 6561, 10000]

# %% [markdown]
# Using an IF clause to filter out the elements.

# %%
quadrup_by_two = [i**4 for i in range(0, 11) if i**4 % 2 == 0]

# %%
quadrup_by_two
# Out:
# [0, 16, 256, 1296, 4096, 10000]

# %%
squares
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
squares_by_four = [i**2 for i in range(1, 11) if i**2 % 4 == 0]

# %%
squares_by_four
# Out:
# [4, 16, 36, 64, 100]

# %%
squares_dict = {i: i**2 for i in range(1, 11)}

# %%
squares_dict
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
cubes_dict = {i:i**3 for i in range(0, 11) if i**3 % 2 == 0}

# %%
cubes_dict
# Out:
# {0: 0, 2: 8, 4: 64, 6: 216, 8: 512, 10: 1000}

# %%
quadrup_dict = {j:j**4 for j in range(0, 10)}

# %%
quadrup_dict
# Out:
# {0: 0, 1: 1, 2: 16, 3: 81, 4: 256, 5: 625, 6: 1296, 7: 2401, 8: 4096, 9: 6561}

# %%
capitals_by_country = {'United States': 'Washington, DC', 
                       'France': 'Paris',
                       'Italy': 'Rome'}

# %% [markdown]
# Transpose --> flipping keys and values in dictionary.

# %%
print(capitals_by_country)
# Out:
# {'United States': 'Washington, DC', 'France': 'Paris', 'Italy': 'Rome'}

# %%
countries_by_capital = {capital: country for country, capital in capitals_by_country.items()}

# %%
fruit_by_color = {
  "red":"apple",
  "yellow": "banana",
  "green": "avocado"
}

# %%
color_by_fruits={fruit: color for color, fruit in fruit_by_color.items()}

# %%
fruit_by_color
# Out:
# {'red': 'apple', 'yellow': 'banana', 'green': 'avocado'}

# %%
color_by_fruits
# Out:
# {'apple': 'red', 'banana': 'yellow', 'avocado': 'green'}

# %% [markdown]
# Countries indexed by capitals.

# %%
countries_by_capital
# Out:
# {'Washington, DC': 'United States', 'Paris': 'France', 'Rome': 'Italy'}

# %% [markdown]
# Capital indexed by countries

# %%
capitals_by_country
# Out:
# {'United States': 'Washington, DC', 'France': 'Paris', 'Italy': 'Rome'}

# %% [markdown]
# Comprehensions are useful when we manipulate lists, dictionaries, and sets of data.

# %%
print(sum(i**2 for i in range(1, 11)))
# Out:
# 385

# %% [markdown]
# Nested for loop

# %% [markdown]
# Make a list of list

# %%
matrix = [[i*j for i in range(1,4)] for j in range(1,4)]

# %%
matrix
# Out:
# [[1, 2, 3], [2, 4, 6], [3, 6, 9]]

# %%
chau_matrix = [i * 2 for i in range(0, 3)]

# %%
chau_matrix
# Out:
# [0, 2, 4]

# %%
chau_matrix_2 = [[i * j for i in range (0, 3)] for j in range (0, 3)]

# %%
chau_matrix_2
# Out:
# [[0, 0, 0], [0, 1, 2], [0, 2, 4]]

# %%
[element for row in matrix for element in row]
# Out:
# [1, 2, 3, 2, 4, 6, 3, 6, 9]

# %%
[row for row in chau_matrix_2]
# Out:
# [[0, 0, 0], [0, 1, 2], [0, 2, 4]]

# %%
chau_matrix_2[0]
# Out:
# [0, 0, 0]

# %%
matrix
# Out:
# [[1, 2, 3], [2, 4, 6], [3, 6, 9]]

# %%
[element for row in matrix for element in row]
# Out:
# [1, 2, 3, 2, 4, 6, 3, 6, 9]

# %%
chau_matrix_2
# Out:
# [[0, 0, 0], [0, 1, 2], [0, 2, 4]]

# %% [markdown]
# Go from inside out. Identify ROW in MATRIX first. Then go to each element in ROW.

# %%
[element for row in chau_matrix_2 for element in row]
# Out:
# [0, 0, 0, 0, 1, 2, 0, 2, 4]
