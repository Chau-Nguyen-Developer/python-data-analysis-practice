# %% [markdown]
# # 01_03: Dictionaries and sets

# %%
import math
import collections
import dataclasses
import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
import math
import collections
import dataclasses
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
capitals = {'United States': 'Washington, DC', 'France': 'Paris', 'Italy': 'Rome'}

# %%
fruits = {
  "red": "apple",
  "orange": "papaya",
  "yellow": "banana",
  "blue": "berries", 
  "green": "avocado", 
  "purple": "eggplant"
}

# %%
type(fruits)
# Out:
# dict

# %%
capitals
# Out:
# {'United States': 'Washington, DC', 'France': 'Paris', 'Italy': 'Rome'}

# %%
fruits
# Out:
# {'red': 'apple',
#  'orange': 'papaya',
#  'yellow': 'banana',
#  'blue': 'berries',
#  'green': 'avocado',
#  'purple': 'eggplant'}

# %%
capitals
# Out:
# {'United States': 'Washington, DC', 'France': 'Paris', 'Italy': 'Rome'}

# %%
len(fruits)
# Out:
# 6

# %%
len(capitals), len({})
# Out:
# (3, 0)

# %%
temp_tuple = (len(fruits), len(capitals))

# %%
temp_tuple
# Out:
# (6, 3)

# %%
capitals
# Out:
# {'United States': 'Washington, DC', 'France': 'Paris', 'Italy': 'Rome'}

# %%
capitals['Italy']
# Out:
# 'Rome'

# %%
fruits["red"]
# Out:
# 'apple'

# %%
capitals
# Out:
# {'United States': 'Washington, DC', 'France': 'Paris', 'Italy': 'Rome'}

# %% [markdown]
# Add in more key-value pairs

# %%
capitals['Spain'] = 'Madrid'

# %%
capitals
# Out:
# {'United States': 'Washington, DC',
#  'France': 'Paris',
#  'Italy': 'Rome',
#  'Spain': 'Madrid'}

# %% [markdown]
# Will receive key error in the below case because there is no key "Germany" in the dictionary.

# %%
# capitals['Germany']

# %% [markdown]
# Check to see if the keys are in dictionary

# %%
'Germany' in capitals, 'Italy' in capitals
# Out:
# (False, True)

# %%
"pink" in fruits, "red" in fruits
# Out:
# (False, True)

# %%
morecapitals = {'Germany': 'Berlin', 'United Kingdom': 'London'}

# %%
morecapitals
# Out:
# {'Germany': 'Berlin', 'United Kingdom': 'London'}

# %%
morefruits = {
  "pink": "dragonfruit",
  "white": "lychee"
  }

# %% [markdown]
# Combine two dictionaries into one dictionary.

# %%
{**capitals, **morecapitals}
# Out:
# {'United States': 'Washington, DC',
#  'France': 'Paris',
#  'Italy': 'Rome',
#  'Spain': 'Madrid',
#  'Germany': 'Berlin',
#  'United Kingdom': 'London'}

# %%
{**fruits, **morefruits}
# Out:
# {'red': 'apple',
#  'orange': 'papaya',
#  'yellow': 'banana',
#  'blue': 'berries',
#  'green': 'avocado',
#  'purple': 'eggplant',
#  'pink': 'dragonfruit',
#  'white': 'lychee'}

# %%
newdict1 = {**capitals, **morecapitals}

# %%
newdict1
# Out:
# {'United States': 'Washington, DC',
#  'France': 'Paris',
#  'Italy': 'Rome',
#  'Spain': 'Madrid',
#  'Germany': 'Berlin',
#  'United Kingdom': 'London'}

# %%
capitals
# Out:
# {'United States': 'Washington, DC',
#  'France': 'Paris',
#  'Italy': 'Rome',
#  'Spain': 'Madrid'}

# %%
morecapitals
# Out:
# {'Germany': 'Berlin', 'United Kingdom': 'London'}

# %%
capitals.update(morecapitals)

# %%
capitals
# Out:
# {'United States': 'Washington, DC',
#  'France': 'Paris',
#  'Italy': 'Rome',
#  'Spain': 'Madrid',
#  'Germany': 'Berlin',
#  'United Kingdom': 'London'}

# %%
morecapitals
# Out:
# {'Germany': 'Berlin', 'United Kingdom': 'London'}

# %%
morecapitals.update(capitals)

# %%
morecapitals
# Out:
# {'Germany': 'Berlin',
#  'United Kingdom': 'London',
#  'United States': 'Washington, DC',
#  'France': 'Paris',
#  'Italy': 'Rome',
#  'Spain': 'Madrid'}

# %%
fruits
# Out:
# {'red': 'apple',
#  'orange': 'papaya',
#  'yellow': 'banana',
#  'blue': 'berries',
#  'green': 'avocado',
#  'purple': 'eggplant'}

# %%
morefruits
# Out:
# {'pink': 'dragonfruit', 'white': 'lychee'}

# %%
newdict2 = {**fruits, **morefruits}

# %%
newdict2
# Out:
# {'red': 'apple',
#  'orange': 'papaya',
#  'yellow': 'banana',
#  'blue': 'berries',
#  'green': 'avocado',
#  'purple': 'eggplant',
#  'pink': 'dragonfruit',
#  'white': 'lychee'}

# %%
fruits
# Out:
# {'red': 'apple',
#  'orange': 'papaya',
#  'yellow': 'banana',
#  'blue': 'berries',
#  'green': 'avocado',
#  'purple': 'eggplant'}

# %%
fruits.update(morefruits)

# %%
fruits
# Out:
# {'red': 'apple',
#  'orange': 'papaya',
#  'yellow': 'banana',
#  'blue': 'berries',
#  'green': 'avocado',
#  'purple': 'eggplant',
#  'pink': 'dragonfruit',
#  'white': 'lychee'}

# %%
capitals
# Out:
# {'United States': 'Washington, DC',
#  'France': 'Paris',
#  'Italy': 'Rome',
#  'Spain': 'Madrid',
#  'Germany': 'Berlin',
#  'United Kingdom': 'London'}

# %%
del capitals["France"]

# %%
capitals
# Out:
# {'United States': 'Washington, DC',
#  'Italy': 'Rome',
#  'Spain': 'Madrid',
#  'Germany': 'Berlin',
#  'United Kingdom': 'London'}

# %%
del capitals["Italy"]

# %%
fruits
# Out:
# {'red': 'apple',
#  'orange': 'papaya',
#  'yellow': 'banana',
#  'blue': 'berries',
#  'green': 'avocado',
#  'purple': 'eggplant',
#  'pink': 'dragonfruit',
#  'white': 'lychee'}

# %%
del fruits["pink"]

# %%
fruits
# Out:
# {'red': 'apple',
#  'orange': 'papaya',
#  'yellow': 'banana',
#  'blue': 'berries',
#  'green': 'avocado',
#  'purple': 'eggplant',
#  'white': 'lychee'}

# %%
capitals
# Out:
# {'United States': 'Washington, DC', 'Spain': 'Madrid'}

# %%
del capitals['United Kingdom']

# %%
capitals
# Out:
# {'United States': 'Washington, DC',
#  'Italy': 'Rome',
#  'Spain': 'Madrid',
#  'Germany': 'Berlin'}

# %%
"Germany" in capitals
# Out:
# True

# %%
("Germany" in capitals, "germaney" in capitals)
# Out:
# (True, False)

# %%
del capitals["Germany"]

# %%
capitals
# Out:
# {'United States': 'Washington, DC', 'Italy': 'Rome', 'Spain': 'Madrid'}

# %%
birthdays = {
  (7,15): 'Michele',
  (3,14): 'Albert',
  (7, 30): "Tommy",
  (5, 14): "Chau"}

# %%
birthdays
# Out:
# {(7, 15): 'Michele', (3, 14): 'Albert', (7, 30): 'Tommy', (5, 14): 'Chau'}

# %%
birthdays[(7,15)]
# Out:
# 'Michele'

# %%
birthdays[(5, 14)]
# Out:
# 'Chau'

# %%
fruits
# Out:
# {'red': 'apple',
#  'orange': 'papaya',
#  'yellow': 'banana',
#  'blue': 'berries',
#  'green': 'avocado',
#  'purple': 'eggplant',
#  'white': 'lychee'}

# %% [markdown]
# Hashable things must never changed.
# A hash is just a number that uniquely represents an object.

# %%
print(hash("blue"))
# Out:
# -3902901713053313514

# %%
hash("blue")
# Out:
# -3902901713053313514

# %%
hash("white"), hash((5,14))
# Out:
# (1502803235791662998, 6453000607958316648)

# %%
hash('Italy'), hash((7,15))
# Out:
# (5183177604346075085, -2471369287409462312)

# %%
fruits
# Out:
# {'red': 'apple',
#  'orange': 'papaya',
#  'yellow': 'banana',
#  'blue': 'berries',
#  'green': 'avocado',
#  'purple': 'eggplant',
#  'white': 'lychee'}

# %%
for color in fruits:
  print(color)
# Out:
# red
# orange
# yellow
# blue
# green
# purple
# white

# %%
for colors in fruits.keys():
  print(colors)
# Out:
# red
# orange
# yellow
# blue
# green
# purple
# white

# %%
for value in fruits.values():
  print(value)
# Out:
# apple
# papaya
# banana
# berries
# avocado
# eggplant
# lychee

# %%
for color, fruit in fruits.items():
  print(color, fruit)
# Out:
# red apple
# orange papaya
# yellow banana
# blue berries
# green avocado
# purple eggplant
# white lychee

# %%
for country in capitals:
    print(country)
# Out:
# United States
# Italy
# Spain

# %%
for country in capitals.keys():
    print(country)
# Out:
# United States
# Italy
# Spain

# %%
capitals.keys()
# Out:
# dict_keys(['United States', 'Italy', 'Spain'])

# %%
type(capitals.keys())
# Out:
# dict_keys

# %%
type(capitals.values())
# Out:
# dict_values

# %%
capitals.values()
# Out:
# dict_values(['Washington, DC', 'Madrid'])

# %%
capitals.items()
# Out:
# dict_items([('United States', 'Washington, DC'), ('Spain', 'Madrid')])

# %%
type(capitals.items())
# Out:
# dict_items

# %%
print(capitals.items())
# Out:
# dict_items([('United States', 'Washington, DC'), ('Spain', 'Madrid')])

# %%
list(capitals.items())
# Out:
# [('United States', 'Washington, DC'), ('Spain', 'Madrid')]

# %%
type(capitals.items())
# Out:
# dict_items

# %%
list(capitals.keys())
# Out:
# ['United States', 'Italy', 'Spain']

# %%
for capital in capitals.values():
    print(capital)
# Out:
# Washington, DC
# Rome
# Madrid

# %%
for country, capital in capitals.items():
    print(country, capital)
# Out:
# United States Washington, DC
# Italy Rome
# Spain Madrid

# %%
capitals.keys()
# Out:
# dict_keys(['United States', 'Italy', 'Spain'])

# %% [markdown]
# Can turn it into list (iterable)

# %%
list(capitals.keys())
# Out:
# ['United States', 'Italy', 'Spain']

# %% [markdown]
# Set up default return instead of error return when a key is not found.

# %%
capitals_default = collections.defaultdict(lambda: "I don't know!")

# %%
fruits_default = collections.defaultdict(lambda: "Hello Chau, I dunno.")

# %%
capitals_default.update(capitals)

# %%
capitals
# Out:
# {'United States': 'Washington, DC', 'Spain': 'Madrid'}

# %%
fruits_default.update(fruits)

# %%
fruits
# Out:
# {'red': 'apple',
#  'orange': 'papaya',
#  'yellow': 'banana',
#  'blue': 'berries',
#  'green': 'avocado',
#  'purple': 'eggplant',
#  'white': 'lychee'}

# %%
fruits_default
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'red': 'apple',
#              'orange': 'papaya',
#              'yellow': 'banana',
#              'blue': 'berries',
#              'green': 'avocado',
#              'purple': 'eggplant',
#              'white': 'lychee'})

# %%
fruits_default["black"]
# Out:
# 'Hello Chau, I dunno.'

# %%
capitals_default['Canada']
# Out:
# "I don't know!"

# %% [markdown]
# This is a set.

# %%
continents = {'America', 'Europe', 'Asia', 'Oceania', 'Africa', 'Africa'}

# %% [markdown]
# List --> unhashable (list is mutable/ able to edit. --> cannot be hashed), so list cannot be in the set.

# %%
# test_set = {[1, 2], [3, 4]}

# %%
names = {"Shannen", "Phuong", "Anna", "Maria", "Maria", "Chau"}

# %% [markdown]
# Set --> no duplicate. When return, it will return with alphabetical order.

# %%
names
# Out:
# {'Anna', 'Chau', 'Maria', 'Phuong', 'Shannen'}

# %%
("Chau" in names, "Minh" in names)
# Out:
# (True, False)

# %%
continents
# Out:
# {'Africa', 'America', 'Asia', 'Europe', 'Oceania'}

# %%
'Africa' in continents
# Out:
# True

# %%
print(names.add("Danny"))
# Out:
# None

# %%
names
# Out:
# {'Anna', 'Chau', 'Danny', 'Maria', 'Phuong', 'Shannen'}

# %%
continents.add('Antarctica')

# %%
continents.remove('Antarctica')

# %%
for c in continents:
    print(c)
# Out:
# Asia
# America
# Europe
# Oceania
# Africa

# %%
for i, c in enumerate(continents):
  print(i, c)
# Out:
# 0 Asia
# 1 America
# 2 Europe
# 3 Oceania
# 4 Africa

# %%
for c in enumerate(continents):
  print(c)
# Out:
# (0, 'Asia')
# (1, 'America')
# (2, 'Europe')
# (3, 'Oceania')
# (4, 'Africa')
